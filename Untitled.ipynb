# %%
print()

# %%
print("hi")
# Out:
# hi

# %%
print("Welcome to Hope Ai")
# Out:
# Welcome to Hope Ai

# %%
Print("Welcome to Hope Ai")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Print("Welcome to Hope Ai")
#
# NameError: name 'Print' is not defined

# %%
print("Welcome to Hope Ai");
# Out:
# Welcome to Hope Ai

# %%
print("jhsdhfkjdhfkjkjshjsd!1234567890")
# Out:
# jhsdhfkjdhfkjkjshjsd!1234567890

# %%
Print("Welcome to Hope Ai")
