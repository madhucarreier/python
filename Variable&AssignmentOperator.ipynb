# %%
Number1=10

# %%
print(Number1)
# Out:
# 10

# %%
add first number=20
print(add first number)
# Out:
#   Cell In[3], line 1
#     add first number=20
#         ^
# SyntaxError: invalid syntax

# %%
addfirstnumber=20
print(addfirstnumber)
# Out:
# 20

# %%
add First number="20"
print(add Firstnumber)
# Out:
#   Cell In[7], line 1
#     add First number="20"
#         ^
# SyntaxError: invalid syntax

# %%
add 45irstnumber="20"
print(add 45irstnumber)
# Out:
#   Cell In[8], line 1
#     add 45irstnumber="20"
#          ^
# SyntaxError: invalid decimal literal

# %%
add 45irstnumber="20"
# Out:
#   Cell In[10], line 1
#     add 45irstnumber="20"
#          ^
# SyntaxError: invalid decimal literal
