# %%
Print("Welcome to Hope Ai")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Print("Welcome to Hope Ai")
#
# NameError: name 'Print' is not defined

# %%
print("Welcome to Hope Ai")
# Out:
# Welcome to Hope Ai

# %%
print(werlcomdhhd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(werlcomdhhd)
#
# NameError: name 'werlcomdhhd' is not defined

# %%
print("Welcome to Hope Ai")
# Out:
# Welcome to Hope Ai

# %%
print("The addition of two numbers")
# Out:
# The addition of two numbers

# %%
addnnumber1=10
print("The addition number1:",addnnumber1)
addnnumber2=20
print("The addition number2:",addnnumber2)
add=addnnumber1 +addnnumber2
print("The Answer is:",add)
# Out:
# The addition number1: 10
# The addition number2: 20
# The Answer is: 30
